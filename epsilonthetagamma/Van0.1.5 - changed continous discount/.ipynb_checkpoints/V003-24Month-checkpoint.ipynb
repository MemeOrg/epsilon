# %%
#error checking measures 
import csv 
import matplotlib.pyplot as plt
numberofGraphs = 15
def csv_dict_writer(path, fieldnames, data):
    with open(path, "wb") as out_file:
        writer = csv.DictWriter(out_file, delimiter=',', fieldnames=fieldnames)
        writer.writeheader()
        for row in data:
            writer.writerow(row)
masterListforReplications = []
field_names = "QALY,TotalCost".split(",")
from PlottingSystemClass import PlottingSystem
from SimulationSystemClass import SimulationSystem
plottingsystem = PlottingSystem(plt)
order = 1
# %matplotlib inline
for i in range(2):
    sysSimulation = SimulationSystem(3000,"PatientList/Patients_list_{}.csv".format(i))
    sysSimulation.SystemSimulation()
    plottingsystem.plot(sysSimulation,order,i,masterListforReplications)
    order += (numberofGraphs*1) 
    del sysSimulation 
print order 
csv_dict_writer("MList.csv",field_names,masterListforReplications)
# Out:
# CURRENT ITERATION: 0
# Average QALY: 12.5992128027
# Average Medical Cost: 25597.7741467
# Average MD: -12.7791813253
#
# CURRENT ITERATION: 1
# Average QALY: 12.5651083938
# Average Medical Cost: 26228.8036167
# Average MD: -12.9349768542
#
# CURRENT ITERATION: 2
# Average QALY: 12.5538084799
# Average Medical Cost: 26116.6120233
# Average MD: -13.0331878336
#
# CURRENT ITERATION: 3
# Average QALY: 12.5534203955
# Average Medical Cost: 26413.2896417
# Average MD: -13.0237844939
#
# CURRENT ITERATION: 4
# Average QALY: 12.5599662878
# Average Medical Cost: 26476.1591733
# Average MD: -12.9521151556
#
# CURRENT ITERATION: 5
# Average QALY: 12.5940761899
# Average Medical Cost: 25983.510665
# Average MD: -12.7759227875
#
# CURRENT ITERATION: 6
# Average QALY: 12.5355893108
# Average Medical Cost: 26533.1145933
# Average MD: -13.103254753
#
# CURRENT ITERATION: 7
# Average QALY: 12.5422478676
# Average Medical Cost: 26459.6344717
# Average MD: -13.0297882291
#
# CURRENT ITERATION: 8
# Average QALY: 12.5700099391
# Average Medical Cost: 25988.926975
# Average MD: -12.8873877947
#
# CURRENT ITERATION: 9
# Average QALY: 12.5717249259
# Average Medical Cost: 26020.4229917
# Average MD: -12.9285578751
#
# CURRENT ITERATION: 10
# Average QALY: 12.5554004399
# Average Medical Cost: 26397.3059867
# Average MD: -13.0191899726
#
# CURRENT ITERATION: 11
# Average QALY: 12.6118208971
# Average Medical Cost: 25589.09265
# Average MD: -12.7409234002
#
# CURRENT ITERATION: 12
# Average QALY: 12.559126155
# Average Medical Cost: 26101.7627067
# Average MD: -12.9567626257
#
# CURRENT ITERATION: 13
# Average QALY: 12.5396759608
# Average Medical Cost: 25897.9487467
# Average MD: -13.0458320964
#
# CURRENT ITERATION: 14
# Average QALY: 12.5857487843
# Average Medical Cost: 25972.4310083
# Average MD: -12.9014517146
#
# CURRENT ITERATION: 15
# Average QALY: 12.5849378634
# Average Medical Cost: 25848.25813
# Average MD: -12.899730601
#
# CURRENT ITERATION: 16
# Average QALY: 12.5661853662
# Average Medical Cost: 26195.84142
# Average MD: -12.9270928238
#
# CURRENT ITERATION: 17
# Average QALY: 12.5742997842
# Average Medical Cost: 26006.3535083
# Average MD: -12.8998540931
#
# CURRENT ITERATION: 18
# Average QALY: 12.5552641924
# Average Medical Cost: 26355.0360517
# Average MD: -12.9923721476
#
# CURRENT ITERATION: 19
# Average QALY: 12.5979635036
# Average Medical Cost: 25863.760765
# Average MD: -12.793681147
#
# CURRENT ITERATION: 20
# Average QALY: 12.5905431918
# Average Medical Cost: 25859.27122
# Average MD: -12.8078956648
#
# CURRENT ITERATION: 21
# Average QALY: 12.5631265221
# Average Medical Cost: 26088.8669783
# Average MD: -12.9600978279
#
# CURRENT ITERATION: 22
# Average QALY: 12.566683728
# Average Medical Cost: 25987.93211
# Average MD: -12.9788096691
#
# CURRENT ITERATION: 23
# Average QALY: 12.5962464587
# Average Medical Cost: 26002.9121483
# Average MD: -12.7846065429
#
# CURRENT ITERATION: 24
# Average QALY: 12.5927211719
# Average Medical Cost: 25893.466875
# Average MD: -12.8087284124
#
# CURRENT ITERATION: 25
# Average QALY: 12.5575818264
# Average Medical Cost: 26367.9376
# Average MD: -12.9872703495
#
# CURRENT ITERATION: 26
# Average QALY: 12.5459969362
# Average Medical Cost: 26410.3979033
# Average MD: -13.0188743233
#
# CURRENT ITERATION: 27
# Average QALY: 12.536356779
# Average Medical Cost: 26629.5733883
# Average MD: -13.0771933206
#
# CURRENT ITERATION: 28
# Average QALY: 12.5648575997
# Average Medical Cost: 26004.811895
# Average MD: -12.9700528434
#
# CURRENT ITERATION: 29
# Average QALY: 12.5373478066
# Average Medical Cost: 26686.7871767
# Average MD: -13.0932273764
#
# 211
# C:\Users\Martin Nguyen\Anaconda\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
