# %%
#error checking measures 
import csv 
import matplotlib.pyplot as plt
numberofGraphs = 15
def csv_dict_writer(path, fieldnames, data):
    with open(path, "wb") as out_file:
        writer = csv.DictWriter(out_file, delimiter=',', fieldnames=fieldnames)
        writer.writeheader()
        for row in data:
            writer.writerow(row)
masterListforReplications = []
field_names = "QALY,TotalCost".split(",")
from PlottingSystemClass import PlottingSystem
from SimulationSystemClass import SimulationSystem
plottingsystem = PlottingSystem(plt)
order = 1
# %matplotlib inline
for i in range(2):
    sysSimulation = SimulationSystem(3000,"PatientList/Patients_list_{}.csv".format(i))
    sysSimulation.SystemSimulation()
    plottingsystem.plot(sysSimulation,order,i,masterListforReplications)
    order += (numberofGraphs*1) 
    del sysSimulation 
print order 
csv_dict_writer("MList.csv",field_names,masterListforReplications)
# Out:
# CURRENT ITERATION: 0
# Average QALY: 12.6972296135
# Average Medical Cost: 27742.1699817
# Average MD: -12.3483959852
#
# CURRENT ITERATION: 1
# Average QALY: 12.6665464499
# Average Medical Cost: 28378.8457317
# Average MD: -12.4631143048
#
# CURRENT ITERATION: 2
# Average QALY: 12.6543332199
# Average Medical Cost: 28257.6822483
# Average MD: -12.5721892552
#
# CURRENT ITERATION: 3
# Average QALY: 12.6515676261
# Average Medical Cost: 28574.1839567
# Average MD: -12.56669214
#
# CURRENT ITERATION: 4
# Average QALY: 12.6616729927
# Average Medical Cost: 28638.1668983
# Average MD: -12.5071130081
#
# CURRENT ITERATION: 5
# Average QALY: 12.6888826727
# Average Medical Cost: 28330.7118633
# Average MD: -12.3571542434
#
# CURRENT ITERATION: 6
# Average QALY: 12.6340978158
# Average Medical Cost: 28687.9186033
# Average MD: -12.6455331458
#
# CURRENT ITERATION: 7
# Average QALY: 12.6392087784
# Average Medical Cost: 28637.102835
# Average MD: -12.5727422145
#
# CURRENT ITERATION: 8
# Average QALY: 12.6583040682
# Average Medical Cost: 28165.4286217
# Average MD: -12.4477361887
#
# CURRENT ITERATION: 9
# Average QALY: 12.6738456817
# Average Medical Cost: 28243.0935617
# Average MD: -12.4558653135
#
# CURRENT ITERATION: 10
# Average QALY: 12.6594692992
# Average Medical Cost: 28503.7846617
# Average MD: -12.5549795452
#
# CURRENT ITERATION: 11
# Average QALY: 12.699633068
# Average Medical Cost: 27759.351335
# Average MD: -12.3101342162
#
# CURRENT ITERATION: 12
# Average QALY: 12.6589913973
# Average Medical Cost: 28275.82902
# Average MD: -12.5100045498
#
# CURRENT ITERATION: 13
# Average QALY: 12.6424731285
# Average Medical Cost: 27996.6183217
# Average MD: -12.5880204842
#
# CURRENT ITERATION: 14
# Average QALY: 12.6826121614
# Average Medical Cost: 28195.0866267
# Average MD: -12.4489270636
#
# CURRENT ITERATION: 15
# Average QALY: 12.6831709859
# Average Medical Cost: 27961.8700633
# Average MD: -12.42166679
#
# CURRENT ITERATION: 16
# Average QALY: 12.6646942168
# Average Medical Cost: 28415.623695
# Average MD: -12.4909489336
#
# CURRENT ITERATION: 17
# Average QALY: 12.6736879058
# Average Medical Cost: 28114.6435517
# Average MD: -12.4488667045
#
# CURRENT ITERATION: 18
# Average QALY: 12.6526358737
# Average Medical Cost: 28571.6384717
# Average MD: -12.5549250487
#
# CURRENT ITERATION: 19
# Average QALY: 12.6889378803
# Average Medical Cost: 27952.575055
# Average MD: -12.3563832327
#
# CURRENT ITERATION: 20
# Average QALY: 12.6899402327
# Average Medical Cost: 28038.272425
# Average MD: -12.3819651831
#
# CURRENT ITERATION: 21
# Average QALY: 12.664509754
# Average Medical Cost: 28313.8254183
# Average MD: -12.5030239278
#
# CURRENT ITERATION: 22
# Average QALY: 12.6681257269
# Average Medical Cost: 28148.9682517
# Average MD: -12.5148115354
#
# CURRENT ITERATION: 23
# Average QALY: 12.6853198945
# Average Medical Cost: 28248.3092733
# Average MD: -12.382795763
#
# CURRENT ITERATION: 24
# Average QALY: 12.6952611055
# Average Medical Cost: 28122.6997033
# Average MD: -12.3517892675
#
# CURRENT ITERATION: 25
# Average QALY: 12.6542051869
# Average Medical Cost: 28569.18325
# Average MD: -12.5408143343
#
# CURRENT ITERATION: 26
# Average QALY: 12.6443326515
# Average Medical Cost: 28527.0286383
# Average MD: -12.5646555463
#
# CURRENT ITERATION: 27
# Average QALY: 12.6377921899
# Average Medical Cost: 28818.916775
# Average MD: -12.6269223935
#
# CURRENT ITERATION: 28
# Average QALY: 12.6589701633
# Average Medical Cost: 28158.8633717
# Average MD: -12.5322947066
#
# CURRENT ITERATION: 29
# Average QALY: 12.6345624618
# Average Medical Cost: 28765.8914183
# Average MD: -12.6423078916
#
# 211
# C:\Users\Martin Nguyen\Anaconda\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
